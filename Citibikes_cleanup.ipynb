# %%
import pandas as pd

# %%
nyc_pd1 = pd.read_csv('data/201701-citibike-tripdata.csv')
nyc_pd2 = pd.read_csv('data/201702-citibike-tripdata.csv')
nyc_pd3 = pd.read_csv('data/201703-citibike-tripdata.csv')
nyc_pd4 = pd.read_csv('data/201704-citibike-tripdata.csv')
nyc_pd5 = pd.read_csv('data/201705-citibike-tripdata.csv')
nyc_pd6 = pd.read_csv('data/201706-citibike-tripdata.csv')
nyc_pd7 = pd.read_csv('data/201707-citibike-tripdata.csv')

# %%
nyc_pd5.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           254  2017-05-01 00:00:13  2017-05-01 00:04:27               511
# 1           248  2017-05-01 00:00:19  2017-05-01 00:04:28               511
# 2          1120  2017-05-01 00:00:19  2017-05-01 00:19:00               242
# 3           212  2017-05-01 00:00:24  2017-05-01 00:03:56               168
# 4           686  2017-05-01 00:00:29  2017-05-01 00:11:55               494
#
#            start station name  start station latitude  \
# 0          E 14 St & Avenue B               40.729387
# 1          E 14 St & Avenue B               40.729387
# 2  Carlton Ave & Flushing Ave               40.697787
# 3             W 18 St & 6 Ave               40.739713
# 4             W 26 St & 8 Ave               40.747348
#
#    start station longitude  end station id          end station name  \
# 0               -73.977724             394         E 9 St & Avenue C
# ...

# %%
nyc_pd1.columns = ['tripduration', 'starttime', 'stoptime', 'start station id', 'start station name', 'start station latitude',
             'start station longitude', 'end station id','end station name', 'end station latitude', 'end station longitude',
             'bikeid','usertype','birth year','gender']

# %%
nyc_pd1.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                 float64
# gender                       int64
# dtype: object

# %%
nyc_pd2.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1          2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
# 2           328  2017-07-01 00:00:08  2017-07-01 00:05:37              3242
# 3          2530  2017-07-01 00:00:11  2017-07-01 00:42:22              2002
# 4          2534  2017-07-01 00:00:15  2017-07-01 00:42:29              2002
#
#                start station name  start station latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
# 2      Schermerhorn St & Court St               40.691029
# 3    Wythe Ave & Metropolitan Ave               40.716887
# 4    Wythe Ave & Metropolitan Ave               40.716887
#
#    start station longitude  end station id          end station name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# ...

# %%
nyc_pd3.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1397  2017-06-01 00:00:02  2017-06-01 00:23:19               515
# 1          1103  2017-06-01 00:00:13  2017-06-01 00:18:37               488
# 2          1810  2017-06-01 00:00:20  2017-06-01 00:30:31               461
# 3          1760  2017-06-01 00:00:24  2017-06-01 00:29:45              2009
# 4          2165  2017-06-01 00:00:33  2017-06-01 00:36:38               360
#
#          start station name  start station latitude  start station longitude  \
# 0          W 43 St & 10 Ave               40.760094               -73.994618
# 1           W 39 St & 9 Ave               40.756458               -73.993722
# 2           E 20 St & 2 Ave               40.735877               -73.982050
# 3  Catherine St & Monroe St               40.711174               -73.996826
# 4      William St & Pine St               40.707179               -74.008873
#
# ...

# %%
(nyc_pd1[nyc_pd1.isnull().any(axis=1)])
# Out:
#          tripduration            starttime             stoptime  \
# 14                720  2017-08-01 00:01:38  2017-08-01 00:13:39
# 26                677  2017-08-01 00:02:24  2017-08-01 00:13:41
# 45               1878  2017-08-01 00:04:31  2017-08-01 00:35:49
# 47               1879  2017-08-01 00:04:38  2017-08-01 00:35:58
# 54               1449  2017-08-01 00:05:55  2017-08-01 00:30:04
# 55                554  2017-08-01 00:05:59  2017-08-01 00:15:14
# 57               1363  2017-08-01 00:06:04  2017-08-01 00:28:47
# 66               1393  2017-08-01 00:06:53  2017-08-01 00:30:07
# 94               5795  2017-08-01 00:09:25  2017-08-01 01:46:01
# 98               1085  2017-08-01 00:09:57  2017-08-01 00:28:03
# 110              2749  2017-08-01 00:10:51  2017-08-01 00:56:41
# 111              2734  2017-08-01 00:10:51  2017-08-01 00:56:25
# 122              1243  2017-08-01 00:12:45  2017-08-01 00:33:28
# 127              1228  2017-08-01 00:12:59  2017-08-01 00:33:27
# ...

# %%
csv_final.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           254  2017-05-01 00:00:13  2017-05-01 00:04:27               511
# 1           248  2017-05-01 00:00:19  2017-05-01 00:04:28               511
# 2          1120  2017-05-01 00:00:19  2017-05-01 00:19:00               242
# 3           212  2017-05-01 00:00:24  2017-05-01 00:03:56               168
# 4           686  2017-05-01 00:00:29  2017-05-01 00:11:55               494
#
#            start station name  start station latitude  \
# 0          E 14 St & Avenue B               40.729387
# 1          E 14 St & Avenue B               40.729387
# 2  Carlton Ave & Flushing Ave               40.697787
# 3             W 18 St & 6 Ave               40.739713
# 4             W 26 St & 8 Ave               40.747348
#
#    start station longitude  end station id          end station name  \
# 0               -73.977724             394         E 9 St & Avenue C
# ...

# %%
csv_final = nyc_pd6.append(nyc_pd7)

# %%
csv_final = csv_final.append(nyc_pd3)

# %%
csv_final = csv_final.append(nyc_pd4)

# %%
csv_final = csv_final.append(nyc_pd5)

# %%
csv_final = csv_final.append(nyc_pd6)

# %%
csv_final = csv_final.append(nyc_pd7)

# %%
csv_final = csv_final.append(nyc_pd8)

# %%
csv_final_df.to_csv('output1.csv')

# %%
nyc_pd5.to_csv('nyc_pd5_citibikes.csv')

# %%
nyc_pd4.to_csv('nyc_pd4_citibikes.csv')
